# %% [markdown]
# <a href="https://colab.research.google.com/github/shoujunfeng/DockerTarBuilder/blob/master/monkeyOCR_AI%E8%B6%85%E5%85%83%E5%9F%9F%E9%A2%91%E9%81%93%E5%88%B6%E4%BD%9C.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #  👉👉👉 我的微信：stoeng

# %%
# !git clone https://github.com/Yuliang-Liu/MonkeyOCR.git
# Out:
# Cloning into 'MonkeyOCR'...
# remote: Enumerating objects: 467, done.
# remote: Counting objects: 100% (165/165), done.
# remote: Compressing objects: 100% (76/76), done.
# remote: Total 467 (delta 105), reused 90 (delta 89), pack-reused 302 (from 2)
# Receiving objects: 100% (467/467), 12.68 MiB | 8.15 MiB/s, done.
# Resolving deltas: 100% (219/219), done.

# %%
# %cd MonkeyOCR

# !pip install .

# !pip install lmdeploy
# Out:
# /content/MonkeyOCR
# Processing /content/MonkeyOCR
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for magic_pdf: filename=magic_pdf-1.1.0-py3-none-any.whl size=885953 sha256=4954316652184c4df0f12c88426b2cfafd236ba63f5ce132b2e5c74bd3fbb15d
#   Stored in directory: /tmp/pip-ephem-wheel-cache-qt2juh8u/wheels/da/c6/d4/30daa53c185f312413b078e1c685c78431beb5f1ebe08a7374
# Successfully built magic_pdf
# ...
#   Attempting uninstall: magic_pdf
#     Found existing installation: magic_pdf 1.1.0
#     Uninstalling magic_pdf-1.1.0:
#       Successfully uninstalled magic_pdf-1.1.0
# ...
#   Using cached lmdeploy-0.9.0-cp311-cp311-manylinux2014_x86_64.whl.metadata (17 kB)
# ...
#   Using cached fire-0.7.0.tar.gz (87 kB)
#   Preparing metadata (setup.py) ... done
# ...
#   Using cached mmengine_lite-0.10.7-py3-none-any.whl.metadata (20 kB)
# ...
#   Using cached outlines-1.0.1-py3-none-any.whl.metadata (27 kB)
# ...
#   Using cached partial_json_parser-0.2.1.1.post6-py3-none-any.whl.metadata (6.1 kB)
# ...

# %%
# !python tools/download_model.py
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/file_download.py:943: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/file_download.py:980: UserWarning: `local_dir_use_symlinks` parameter is deprecated and will be ignored. The process to download files to a local folder has been updated and do not rely on symlinks anymore. You only need to pass a destination folder as`local_dir`.
# For more details, check out https://huggingface.co/docs/huggingface_hub/main/en/guides/download#download-files-to-local-folder.
#   warnings.warn(
# Fetching 19 files:   0% 0/19 [00:00<?, ?it/s]
# model-00001-of-00002.safetensors:   0% 0.00/5.00G [00:00<?, ?B/s]
# model-00001-of-00002.safetensors:   1% 31.5M/5.00G [00:00<00:19, 250MB/s]
#
# ...

# %%
# !python demo/demo_gradio.py
# Out:
# 2025-06-24 10:14:44.819685: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1750760084.848732    8154 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1750760084.854524    8154 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# !pwd
# Out:
# /content/MonkeyOCR

# %%
# !python parse.py /content/load_v_error.pdf
# Out:
# 2025-06-23 12:39:44.064000: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1750682384.086424   16227 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1750682384.093177   16227 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Loading model...
# ...

# %%
import shutil
from google.colab import files

# 直接运行这三行即可
path = '/content/MonkeyOCR/output/load_v_error/'  # 修改这里的路径
shutil.make_archive('download', 'zip', path)
files.download('download.zip')
